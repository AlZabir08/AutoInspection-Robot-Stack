# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/YOLO-datasets/crack detection"
# Out:
# datasets  runs	yolo11n-seg.pt

# %%
# !ls "/content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/images/train" | head
# !ls "/content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/labels/train" | head
# Out:
# 10.rf.1be181322657e5592be06e9ed277e0b3.jpg
# 10.rf.c00d0aefdcdaee98c7e1a821da0724d9.jpg
# 10.rf.eabd363770a56fc07783cda4bed7d276.jpg
# 1177.rf.6bb0830b57f7fd1ed4aa0dbabb8688c2.jpg
# 1177.rf.a940ca1af97795c8438820a9003156a1.jpg
# 1177.rf.c0bd651b5143023232bf5bdfcc735a71.jpg
# 1212.rf.47327a2f0cfd0d93213066fc52fe2650.jpg
# 1212.rf.80ae3c1ff03d713bc845b9878af03c9a.jpg
# 1212.rf.f430748755bef3588eaf9a0ec58b6c69.jpg
# 1231.rf.104ee9fb0ca467980d6fbc8dc84554e9.jpg
# 10.rf.1be181322657e5592be06e9ed277e0b3.txt
# 10.rf.c00d0aefdcdaee98c7e1a821da0724d9.txt
# 10.rf.eabd363770a56fc07783cda4bed7d276.txt
# 1177.rf.6bb0830b57f7fd1ed4aa0dbabb8688c2.txt
# 1177.rf.a940ca1af97795c8438820a9003156a1.txt
# 1177.rf.c0bd651b5143023232bf5bdfcc735a71.txt
# 1212.rf.47327a2f0cfd0d93213066fc52fe2650.txt
# 1212.rf.80ae3c1ff03d713bc845b9878af03c9a.txt
# 1212.rf.f430748755bef3588eaf9a0ec58b6c69.txt
# 1231.rf.104ee9fb0ca467980d6fbc8dc84554e9.txt

# %%
data_yaml_path = "/content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/data.yaml"

data_yaml_content = """
train: /content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/images/train
val: /content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/images/val
test: /content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/images/test

nc: 1
names: ['crack']
"""

with open(data_yaml_path, "w") as f:
    f.write(data_yaml_content)

print("data.yaml updated successfully!")
# Out:
# data.yaml updated successfully!

# %%
# !pip install ultralytics --upgrade
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 42.4 MB/s eta 0:00:00
# ...

# %%
import torch
print(torch.cuda.is_available())
# !nvidia-smi
# Out:
# True
# Fri Nov 14 09:10:47 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   37C    P8              9W /   70W |       2MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !ls "/content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/images"
# Out:
# test  train  val

# %%
# !yolo train model="/content/drive/MyDrive/YOLO-datasets/crack detection/yolo11n-seg.pt" \
data="/content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/data.yaml" \
epochs=50 imgsz=640 device=0
# Out:
# Ultralytics 8.3.228 🚀 Python-3.12.12 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !ls -R "/content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/runs/"
# Out:
# ls: cannot access '/content/drive/MyDrive/YOLO-datasets/crack detection/datasets/crack-seg/runs/': No such file or directory

# %%
pwd
# Out:
# '/content'

# %%
# !ls -R runs/
# Out:
# runs/:
# segment
#
# runs/segment:
# train  train2
#
# runs/segment/train:
# args.yaml  weights
#
# runs/segment/train/weights:
#
# runs/segment/train2:
# args.yaml			 MaskP_curve.png      train_batch9321.jpg
# BoxF1_curve.png			 MaskPR_curve.png     train_batch9322.jpg
# BoxP_curve.png			 MaskR_curve.png      val_batch0_labels.jpg
# BoxPR_curve.png			 results.csv	      val_batch0_pred.jpg
# BoxR_curve.png			 results.png	      val_batch1_labels.jpg
# confusion_matrix_normalized.png  train_batch0.jpg     val_batch1_pred.jpg
# confusion_matrix.png		 train_batch1.jpg     val_batch2_labels.jpg
# labels.jpg			 train_batch2.jpg     val_batch2_pred.jpg
# MaskF1_curve.png		 train_batch9320.jpg  weights
#
# runs/segment/train2/weights:
# best.pt  last.pt

# %%
# !find /content -type d -name "runs"
# Out:
# /content/runs
# /content/drive/MyDrive/YOLO-datasets/crack detection/runs
# /content/drive/.Encrypted/MyDrive/YOLO-datasets/crack detection/runs

# %%
# !zip -r runs.zip /content/runs
# Out:
#   adding: content/runs/ (stored 0%)
#   adding: content/runs/segment/ (stored 0%)
#   adding: content/runs/segment/train/ (stored 0%)
#   adding: content/runs/segment/train/args.yaml (deflated 53%)
#   adding: content/runs/segment/train/weights/ (stored 0%)
#   adding: content/runs/segment/train2/ (stored 0%)
#   adding: content/runs/segment/train2/BoxR_curve.png (deflated 16%)
#   adding: content/runs/segment/train2/val_batch0_pred.jpg (deflated 5%)
#   adding: content/runs/segment/train2/val_batch0_labels.jpg (deflated 6%)
#   adding: content/runs/segment/train2/train_batch9322.jpg (deflated 7%)
#   adding: content/runs/segment/train2/results.csv (deflated 60%)
#   adding: content/runs/segment/train2/train_batch9320.jpg (deflated 5%)
#   adding: content/runs/segment/train2/MaskR_curve.png (deflated 17%)
#   adding: content/runs/segment/train2/BoxF1_curve.png (deflated 16%)
#   adding: content/runs/segment/train2/args.yaml (deflated 53%)
# ...

# %%
from google.colab import files
files.download("runs.zip")
